# %%
# import libraries
import json

from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.avro.functions import from_avro, to_avro
from pyspark.sql.functions import col, current_timestamp, struct, to_json, lit

# %%
def get_avro_schema(spark_df, schema_type: str, name: str, namespace: str):
    """
    Returns the corresponding avro schema for the passed in spark dataframe.
    The type mapping covers most commonly used types, every field is made to be nullable.
    """

    schema_base = {"type": schema_type, "namespace": namespace, "name": name}

    # Keys are Spark Types, Values are Avro Types
    avro_mapping = {
        "StringType": ["string", "null"],
        "LongType": ["long", "null"],
        "IntegerType": ["int", "null"],
        "BooleanType": ["boolean", "null"],
        "FloatType": ["float", "null"],
        "DoubleType": ["double", "null"],
        "TimestampType": ["long", "null"],
        "ArrayType(StringType,true)": [
            {"type": "array", "items": ["string", "null"]},
            "null",
        ],
        "ArrayType(IntegerType,true)": [
            {"type": "array", "items": ["int", "null"]},
            "null",
        ],
    }

    fields = []

    for field in spark_df.schema.fields:
        if str(field.dataType) in avro_mapping:
            fields.append(
                {"name": field.name, "type": avro_mapping[str(field.dataType)]}
            )
        else:
            fields.append({"name": field.name, "type": str(field.dataType)})

    schema_base["fields"] = fields

    return json.dumps(schema_base)
def generate_avro_schema_from_json(json_data):
    def avro_type_mapping(value):
        if value is None:
            return ["null", "string"]
        elif isinstance(value, bool):
            return ["null", "boolean"]
        elif isinstance(value, int):
            return ["null", "int"]
        elif isinstance(value, float):
            return ["null", "double"]
        elif isinstance(value, str):
            return ["null", "string"]
        else:
            return ["null", "string"]

    avro_schema = {
        "type": "record",
        "name": "Default_schema",
        "fields": [
            {"name": key, "type": avro_type_mapping(value)}
            for key, value in json_data.items()
        ],
    }
    return avro_schema

# %%
# init session
spark = (
    SparkSession.builder.appName("delivery-data-from-sap-hana-to-kafka")
    .config(
        "spark.jars.packages",
        "org.postgresql:postgresql:42.7.1,"+
        "com.sap.cloud.db.jdbc:ngdbc:2.19.15,"+
        "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0,"+
        "org.apache.spark:spark-avro_2.12:3.5.0,"+
        "org.apache.kafka:kafka-clients:3.5.0,"+
        "org.apache.spark:spark-streaming-kafka-0-10_2.12:3.5.0",
    )
    .enableHiveSupport()
    .getOrCreate()
)

# %%
df = spark\
  .read\
  .format("kafka")\
  .option("kafka.bootstrap.servers", "broker:29092")\
  .option("subscribe", "topic2")\
  .load()

# %%
df.collect()
# Out:
# [Row(key=None, value=bytearray(b'{"id":1,"name":"Paul","age":32,"address":"California                                        ","salary":20000.0}'), topic='topic2', partition=0, offset=0, timestamp=datetime.datetime(2023, 12, 20, 3, 36, 51, 554000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":2,"name":"Allen","age":25,"address":"Texas                                             ","salary":15000.0}'), topic='topic2', partition=0, offset=1, timestamp=datetime.datetime(2023, 12, 20, 3, 36, 51, 563000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":3,"name":"Teddy","age":23,"address":"Norway                                            ","salary":20000.0}'), topic='topic2', partition=0, offset=2, timestamp=datetime.datetime(2023, 12, 20, 3, 36, 51, 563000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":4,"name":"Mark","age":25,"address":"Rich-Mond                                         ","salary":65000.0}'), topic='topic2', partition=0, offset=3, timestamp=datetime.datetime(2023, 12, 20, 3, 36, 51, 565000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":5,"name":"David","age":27,"address":"Texas                                             ","salary":85000.0}'), topic='topic2', partition=0, offset=4, timestamp=datetime.datetime(2023, 12, 20, 3, 36, 51, 565000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":6,"name":"Kim","age":22,"address":"South-Hall                                        ","salary":45000.0}'), topic='topic2', partition=0, offset=5, timestamp=datetime.datetime(2023, 12, 20, 3, 36, 51, 565000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":7,"name":"James","age":24,"address":"Houston                                           ","salary":10000.0}'), topic='topic2', partition=0, offset=6, timestamp=datetime.datetime(2023, 12, 20, 3, 36, 51, 565000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":1,"name":"Paul","age":32,"address":"California                                        ","salary":20000.0}'), topic='topic2', partition=0, offset=7, timestamp=datetime.datetime(2023, 12, 20, 3, 41, 32, 785000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":2,"name":"Allen","age":25,"address":"Texas                                             ","salary":15000.0}'), topic='topic2', partition=0, offset=8, timestamp=datetime.datetime(2023, 12, 20, 3, 41, 32, 794000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":3,"name":"Teddy","age":23,"address":"Norway                                            ","salary":20000.0}'), topic='topic2', partition=0, offset=9, timestamp=datetime.datetime(2023, 12, 20, 3, 41, 32, 794000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":4,"name":"Mark","age":25,"address":"Rich-Mond                                         ","salary":65000.0}'), topic='topic2', partition=0, offset=10, timestamp=datetime.datetime(2023, 12, 20, 3, 41, 32, 794000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":5,"name":"David","age":27,"address":"Texas                                             ","salary":85000.0}'), topic='topic2', partition=0, offset=11, timestamp=datetime.datetime(2023, 12, 20, 3, 41, 32, 794000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":6,"name":"Kim","age":22,"address":"South-Hall                                        ","salary":45000.0}'), topic='topic2', partition=0, offset=12, timestamp=datetime.datetime(2023, 12, 20, 3, 41, 32, 794000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":7,"name":"James","age":24,"address":"Houston                                           ","salary":10000.0}'), topic='topic2', partition=0, offset=13, timestamp=datetime.datetime(2023, 12, 20, 3, 41, 32, 795000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":1,"name":"Paul","age":32,"address":"California                                        ","salary":20000.0}'), topic='topic2', partition=0, offset=14, timestamp=datetime.datetime(2023, 12, 20, 3, 43, 9, 778000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":2,"name":"Allen","age":25,"address":"Texas                                             ","salary":15000.0}'), topic='topic2', partition=0, offset=15, timestamp=datetime.datetime(2023, 12, 20, 3, 43, 9, 778000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":3,"name":"Teddy","age":23,"address":"Norway                                            ","salary":20000.0}'), topic='topic2', partition=0, offset=16, timestamp=datetime.datetime(2023, 12, 20, 3, 43, 9, 778000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":4,"name":"Mark","age":25,"address":"Rich-Mond                                         ","salary":65000.0}'), topic='topic2', partition=0, offset=17, timestamp=datetime.datetime(2023, 12, 20, 3, 43, 9, 778000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":5,"name":"David","age":27,"address":"Texas                                             ","salary":85000.0}'), topic='topic2', partition=0, offset=18, timestamp=datetime.datetime(2023, 12, 20, 3, 43, 9, 778000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":6,"name":"Kim","age":22,"address":"South-Hall                                        ","salary":45000.0}'), topic='topic2', partition=0, offset=19, timestamp=datetime.datetime(2023, 12, 20, 3, 43, 9, 779000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":7,"name":"James","age":24,"address":"Houston                                           ","salary":10000.0}'), topic='topic2', partition=0, offset=20, timestamp=datetime.datetime(2023, 12, 20, 3, 43, 9, 779000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":1,"name":"Paul","age":32,"address":"California                                        ","salary":20000.0}'), topic='topic2', partition=0, offset=21, timestamp=datetime.datetime(2023, 12, 20, 3, 47, 38, 874000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":2,"name":"Allen","age":25,"address":"Texas                                             ","salary":15000.0}'), topic='topic2', partition=0, offset=22, timestamp=datetime.datetime(2023, 12, 20, 3, 47, 38, 874000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":3,"name":"Teddy","age":23,"address":"Norway                                            ","salary":20000.0}'), topic='topic2', partition=0, offset=23, timestamp=datetime.datetime(2023, 12, 20, 3, 47, 38, 875000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":4,"name":"Mark","age":25,"address":"Rich-Mond                                         ","salary":65000.0}'), topic='topic2', partition=0, offset=24, timestamp=datetime.datetime(2023, 12, 20, 3, 47, 38, 875000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":5,"name":"David","age":27,"address":"Texas                                             ","salary":85000.0}'), topic='topic2', partition=0, offset=25, timestamp=datetime.datetime(2023, 12, 20, 3, 47, 38, 875000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":6,"name":"Kim","age":22,"address":"South-Hall                                        ","salary":45000.0}'), topic='topic2', partition=0, offset=26, timestamp=datetime.datetime(2023, 12, 20, 3, 47, 38, 875000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":7,"name":"James","age":24,"address":"Houston                                           ","salary":10000.0}'), topic='topic2', partition=0, offset=27, timestamp=datetime.datetime(2023, 12, 20, 3, 47, 38, 875000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":1,"name":"Paul","age":32,"address":"California                                        ","salary":20000.0,"ingestion_time":"2023-12-20T03:48:07.502Z","source_system":"sap","user_name":"gersonrs","ingestion_type":"spark","base_format":"table","rows_written":7,"schema":"{\\"fields\\":[{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"id\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"name\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"age\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"__CHAR_VARCHAR_TYPE_STRING\\":\\"char(50)\\",\\"scale\\":0},\\"name\\":\\"address\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":8},\\"name\\":\\"salary\\",\\"nullable\\":true,\\"type\\":\\"float\\"}],\\"type\\":\\"struct\\"}"}'), topic='topic2', partition=0, offset=28, timestamp=datetime.datetime(2023, 12, 20, 3, 48, 7, 545000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":2,"name":"Allen","age":25,"address":"Texas                                             ","salary":15000.0,"ingestion_time":"2023-12-20T03:48:07.502Z","source_system":"sap","user_name":"gersonrs","ingestion_type":"spark","base_format":"table","rows_written":7,"schema":"{\\"fields\\":[{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"id\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"name\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"age\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"__CHAR_VARCHAR_TYPE_STRING\\":\\"char(50)\\",\\"scale\\":0},\\"name\\":\\"address\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":8},\\"name\\":\\"salary\\",\\"nullable\\":true,\\"type\\":\\"float\\"}],\\"type\\":\\"struct\\"}"}'), topic='topic2', partition=0, offset=29, timestamp=datetime.datetime(2023, 12, 20, 3, 48, 7, 546000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":3,"name":"Teddy","age":23,"address":"Norway                                            ","salary":20000.0,"ingestion_time":"2023-12-20T03:48:07.502Z","source_system":"sap","user_name":"gersonrs","ingestion_type":"spark","base_format":"table","rows_written":7,"schema":"{\\"fields\\":[{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"id\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"name\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"age\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"__CHAR_VARCHAR_TYPE_STRING\\":\\"char(50)\\",\\"scale\\":0},\\"name\\":\\"address\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":8},\\"name\\":\\"salary\\",\\"nullable\\":true,\\"type\\":\\"float\\"}],\\"type\\":\\"struct\\"}"}'), topic='topic2', partition=0, offset=30, timestamp=datetime.datetime(2023, 12, 20, 3, 48, 7, 546000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":4,"name":"Mark","age":25,"address":"Rich-Mond                                         ","salary":65000.0,"ingestion_time":"2023-12-20T03:48:07.502Z","source_system":"sap","user_name":"gersonrs","ingestion_type":"spark","base_format":"table","rows_written":7,"schema":"{\\"fields\\":[{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"id\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"name\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"age\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"__CHAR_VARCHAR_TYPE_STRING\\":\\"char(50)\\",\\"scale\\":0},\\"name\\":\\"address\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":8},\\"name\\":\\"salary\\",\\"nullable\\":true,\\"type\\":\\"float\\"}],\\"type\\":\\"struct\\"}"}'), topic='topic2', partition=0, offset=31, timestamp=datetime.datetime(2023, 12, 20, 3, 48, 7, 546000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":5,"name":"David","age":27,"address":"Texas                                             ","salary":85000.0,"ingestion_time":"2023-12-20T03:48:07.502Z","source_system":"sap","user_name":"gersonrs","ingestion_type":"spark","base_format":"table","rows_written":7,"schema":"{\\"fields\\":[{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"id\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"name\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"age\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"__CHAR_VARCHAR_TYPE_STRING\\":\\"char(50)\\",\\"scale\\":0},\\"name\\":\\"address\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":8},\\"name\\":\\"salary\\",\\"nullable\\":true,\\"type\\":\\"float\\"}],\\"type\\":\\"struct\\"}"}'), topic='topic2', partition=0, offset=32, timestamp=datetime.datetime(2023, 12, 20, 3, 48, 7, 546000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":6,"name":"Kim","age":22,"address":"South-Hall                                        ","salary":45000.0,"ingestion_time":"2023-12-20T03:48:07.502Z","source_system":"sap","user_name":"gersonrs","ingestion_type":"spark","base_format":"table","rows_written":7,"schema":"{\\"fields\\":[{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"id\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"name\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"age\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"__CHAR_VARCHAR_TYPE_STRING\\":\\"char(50)\\",\\"scale\\":0},\\"name\\":\\"address\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":8},\\"name\\":\\"salary\\",\\"nullable\\":true,\\"type\\":\\"float\\"}],\\"type\\":\\"struct\\"}"}'), topic='topic2', partition=0, offset=33, timestamp=datetime.datetime(2023, 12, 20, 3, 48, 7, 546000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"id":7,"name":"James","age":24,"address":"Houston                                           ","salary":10000.0,"ingestion_time":"2023-12-20T03:48:07.502Z","source_system":"sap","user_name":"gersonrs","ingestion_type":"spark","base_format":"table","rows_written":7,"schema":"{\\"fields\\":[{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"id\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"name\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":0},\\"name\\":\\"age\\",\\"nullable\\":true,\\"type\\":\\"integer\\"},{\\"metadata\\":{\\"__CHAR_VARCHAR_TYPE_STRING\\":\\"char(50)\\",\\"scale\\":0},\\"name\\":\\"address\\",\\"nullable\\":true,\\"type\\":\\"string\\"},{\\"metadata\\":{\\"scale\\":8},\\"name\\":\\"salary\\",\\"nullable\\":true,\\"type\\":\\"float\\"}],\\"type\\":\\"struct\\"}"}'), topic='topic2', partition=0, offset=34, timestamp=datetime.datetime(2023, 12, 20, 3, 48, 7, 547000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"to_avro(to_json(struct(value)))":"AJICeyJ2YWx1ZSI6IntcImlkXCI6MSxcIm5hbWVcIjpcIlBhdWxcIixcImFnZVwiOjMyLFwiYWRkcmVzc1wiOlwiQ2FsaWZvcm5pYSAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICBcIixcInNhbGFyeVwiOjIwMDAwLjB9In0="}'), topic='topic2', partition=0, offset=35, timestamp=datetime.datetime(2023, 12, 20, 4, 28, 36, 967000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"to_avro(to_json(struct(value)))":"AJQCeyJ2YWx1ZSI6IntcImlkXCI6MixcIm5hbWVcIjpcIkFsbGVuXCIsXCJhZ2VcIjoyNSxcImFkZHJlc3NcIjpcIlRleGFzICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgXCIsXCJzYWxhcnlcIjoxNTAwMC4wfSJ9"}'), topic='topic2', partition=0, offset=36, timestamp=datetime.datetime(2023, 12, 20, 4, 28, 36, 967000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"to_avro(to_json(struct(value)))":"AJQCeyJ2YWx1ZSI6IntcImlkXCI6MyxcIm5hbWVcIjpcIlRlZGR5XCIsXCJhZ2VcIjoyMyxcImFkZHJlc3NcIjpcIk5vcndheSAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICA
AgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgIFwiLFwic2FsYXJ5XCI6NDUwMDAuMH0ifQ=="}'), topic='topic2', partition=0, offset=61, timestamp=datetime.datetime(2023, 12, 20, 4, 48, 6, 548000), timestampType=0),
#  Row(key=None, value=bytearray(b'{"value":"AJQCeyJ2YWx1ZSI6IntcImlkXCI6NyxcIm5hbWVcIjpcIkphbWVzXCIsXCJhZ2VcIjoyNCxcImFkZHJlc3NcIjpcIkhvdXN0b24gICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgICAgXCIsXCJzYWxhcnlcIjoxMDAwMC4wfSJ9"}'), topic='topic2', partition=0, offset=62, timestamp=datetime.datetime(2023, 12, 20, 4, 48, 6, 548000), timestampType=0),
#  Row(key=None, value=bytearray(b'\x00\x92\x02{"value":"{\\"id\\":1,\\"name\\":\\"Paul\\",\\"age\\":32,\\"address\\":\\"California                                        \\",\\"salary\\":20000.0}"}'), topic='topic2', partition=0, offset=63, timestamp=datetime.datetime(2023, 12, 20, 4, 56, 55, 448000), timestampType=0),
#  Row(key=None, value=bytearray(b'\x00\x94\x02{"value":"{\\"id\\":2,\\"name\\":\\"Allen\\",\\"age\\":25,\\"address\\":\\"Texas                                             \\",\\"salary\\":15000.0}"}'), topic='topic2', partition=0, offset=64, timestamp=datetime.datetime(2023, 12, 20, 4, 56, 55, 449000), timestampType=0),
#  Row(key=None, value=bytearray(b'\x00\x94\x02{"value":"{\\"id\\":3,\\"name\\":\\"Teddy\\",\\"age\\":23,\\"address\\":\\"Norway                                            \\",\\"salary\\":20000.0}"}'), topic='topic2', partition=0, offset=65, timestamp=datetime.datetime(2023, 12, 20, 4, 56, 55, 449000), timestampType=0),
#  Row(key=None, value=bytearray(b'\x00\x92\x02{"value":"{\\"id\\":4,\\"name\\":\\"Mark\\",\\"age\\":25,\\"address\\":\\"Rich-Mond                                         \\",\\"salary\\":65000.0}"}'), topic='topic2', partition=0, offset=66, timestamp=datetime.datetime(2023, 12, 20, 4, 56, 55, 449000), timestampType=0),
#  Row(key=None, value=bytearray(b'\x00\x94\x02{"value":"{\\"id\\":5,\\"name\\":\\"David\\",\\"age\\":27,\\"address\\":\\"Texas                                             \\",\\"salary\\":85000.0}"}'), topic='topic2', partition=0, offset=67, timestamp=datetime.datetime(2023, 12, 20, 4, 56, 55, 449000), timestampType=0),
#  Row(key=None, value=bytearray(b'\x00\x90\x02{"value":"{\\"id\\":6,\\"name\\":\\"Kim\\",\\"age\\":22,\\"address\\":\\"South-Hall                                        \\",\\"salary\\":45000.0}"}'), topic='topic2', partition=0, offset=68, timestamp=datetime.datetime(2023, 12, 20, 4, 56, 55, 449000), timestampType=0),
#  Row(key=None, value=bytearray(b'\x00\x94\x02{"value":"{\\"id\\":7,\\"name\\":\\"James\\",\\"age\\":24,\\"address\\":\\"Houston                                           \\",\\"salary\\":10000.0}"}'), topic='topic2', partition=0, offset=69, timestamp=datetime.datetime(2023, 12, 20, 4, 56, 55, 449000), timestampType=0)]
